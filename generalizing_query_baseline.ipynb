# %%
import pandas as pd
import numpy as np
import itertools
import random
import itertools

def create_imdb(): 
    df = pd.read_csv('imdb.tsv', sep='\t', nrows=1000)
    print(df['genres'].nunique())
    print(df['genres'].count())
    #print(df['genres'])
    return df

def create_queries(df,ref_keyword):
    qs = df[df['genres'].str.contains(ref_keyword,na=False)]['genres']
    #print('query count',len(list(set(qs.tolist()))))
    return list(set(qs.tolist()))

def create_candidates_multiple_predicates(df,ref_keyword,pred_num):
    preds = set(df[df['genres'].str.contains(ref_keyword,na=False)]['genres'])
    return list(itertools.combinations(preds, pred_num))
   
def query_result(df,preds): 
    if type(preds) is not tuple:
        preds = [preds]
    else:
        preds = list(preds)
    return set(df.index[df['genres'].isin(preds)].tolist()) 
            
def get_all_results(df,qs):
    res = {}
    for q in qs: 
        res[q] = query_result(df,q)
    return res
    
def utility(real_query_res, cand_res):
    if not real_query_res.issubset(cand_res):
        return 0
    return 1.0/(len(cand_res.symmetric_difference(real_query_res))+1)

def cands_utility(cands,real_query,res):
    return [utility(res[real_query],res[c]) for c in cands]

def get_valid_candidates(query,cands,all_res):
    vcands = []
    for c in cands:
        #if query in c:
        #    continue
        if all_res[str(query)].issubset(all_res[str(c)]):
            vcands.append(c)
    if len(vcands) == 0:
        print('no containing query', query)
        #print('num of containing candidates:',len(vcands))
    return vcands

def private_query(real_query,epsilon,cands,res,sensitivity):
    # get the score of all candidates
    scores = cands_utility(cands,real_query,res)
    # exponential mechanism
    # sensitivity is assumed to be 1
    # Calculate the probability for each element, based on its score
    probabilities = [np.exp(epsilon * s / (2 * sensitivity)) for s in scores]
    # Normalize the probabilties so they sum to 1
    probabilities = probabilities / np.linalg.norm(probabilities, ord=1)
    # Choose a candidate based on the probabilities
    return cands[np.random.choice(list(range(0,len(scores))), 1, p=probabilities)[0]]

    

def main(keyword,gencont):
    df = create_imdb()
    ref_keyword = keyword #''#'Drama,Short'
    epsilon = 1 
    sensitivity = 1
    # get queries
    qs = create_queries(df,ref_keyword)
    qs = random.sample(qs, min(len(qs),20))
    # candidates with multiple predicates
    #cands = create_candidates(df, ref_keyword)
    cands = create_candidates_multiple_predicates(df,ref_keyword,2)
    print('cand count:',len(cands))
    # compute all query and candidate results
    all_res = get_all_results(df,qs).copy()
    all_res.update(get_all_results(df,cands))
    for q in qs:
        # filter candidates that do not contain query 
        if gencont:
            val_cands = get_valid_candidates(q,cands,all_res)
        else:
            val_cands = cands
        if len(val_cands) == 0:
            continue
        pq = private_query(q,epsilon,val_cands,all_res,sensitivity)
        print('query:',q)
        #print('query result:',all_res[q])
        print('private query:',pq)
        #print('private query result:',all_res[pq])
    
    
main('Drama,Short',gencont=True)
# Out:
# 88
# 1000
# cand count: 36
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [189], line 100
#      96         print('private query:',pq)
#      97         #print('private query result:',all_res[pq])
# --> 100 main('Drama,Short',gencont=True)
#
# Cell In [189], line 88, in main(keyword, gencont)
#      85 for q in qs:
#      86     # filter candidates that do not contain query
#      87     if gencont:
# ---> 88         val_cands = get_valid_candidates(q,cands,all_res)
#      89     else:
#      90         val_cands = cands
#
# Cell In [189], line 49, in get_valid_candidates(query, cands, all_res)
#      45 vcands = []
#      46 for c in cands:
#      47     #if query in c:
#      48     #    continue
# ---> 49     if all_res[str(query)].issubset(all_res[str(c)]):
#      50         vcands.append(c)
#      51 if len(vcands) == 0:
#
# KeyError: "('Comedy,Drama,Short', 'Adventure,Drama,Short')"

# %%
# here, the candidates are generated by enumerating pairs of values in the domain of a query column ('Model Name')
import pandas as pd
import numpy as np
import itertools
import random
import itertools

def create_imdb(): 
    df = pd.read_csv('imdb.tsv', sep='\t', nrows=1000)
    print(df['genres'].nunique())
    print(df['genres'].count())
    print(df)
    return df

def create_ebay(): 
    df = pd.read_csv('ebay_product.csv')
    print(df['Model Name'].nunique())
    print(df['Model Name'].count())
    return df

def create_queries(df,query_column,ref_keyword):
    qs = df[df[query_column].str.contains(ref_keyword,na=False)][query_column]
    print('query count',len(list(set(qs.tolist()))))
    return list(set(qs.tolist()))

def create_candidates_multiple_predicates(df,query_column,ref_keyword,pred_num):
    preds = set(df[df[query_column].str.contains(ref_keyword,na=False)][query_column])
    return list(itertools.combinations(preds, pred_num))
   
def query_result(df,query_column,preds): 
    if type(preds) is not tuple:
        preds = [preds]
    else:
        preds = list(preds)
    return set(df.index[df[query_column].isin(preds)].tolist()) 
            
def get_all_results(df,query_column,qs):
    res = {}
    for q in qs: 
        res[q] = query_result(df,query_column,q)
    return res
    
def utility(real_query_res, cand_res):
    if not real_query_res.issubset(cand_res):
        return 0
    return 1.0/(len(cand_res.symmetric_difference(real_query_res))+1)

def cands_utility(cands,real_query,res):
    return [utility(res[real_query],res[c]) for c in cands]

def get_valid_candidates(query,cands,all_res):
    vcands = []
    for c in cands:
        #if query in c:
        #    continue
        if all_res[query].issubset(all_res[c]):
            vcands.append(c)
    if len(vcands) == 0:
        print('no containing query', query)
        #print('num of containing candidates:',len(vcands))
    return vcands

def private_query(real_query,epsilon,cands,res,sensitivity):
    # get the score of all candidates
    scores = cands_utility(cands,real_query,res)
    # exponential mechanism
    # sensitivity is assumed to be 1
    # Calculate the probability for each element, based on its score
    probabilities = [np.exp(epsilon * s / (2 * sensitivity)) for s in scores]
    # Normalize the probabilties so they sum to 1
    probabilities = probabilities / np.linalg.norm(probabilities, ord=1)
    # Choose a candidate based on the probabilities
    return cands[np.random.choice(list(range(0,len(scores))), 1, p=probabilities)[0]]

    

def main(dataset,keyword,query_column,gencont):
    if dataset=='imdb':
        df = create_imdb()
    if dataset=='ebay':
        df = create_ebay()
    ref_keyword = keyword 
    epsilon = 1 
    sensitivity = 1
    # get queries
    qs = create_queries(df,query_column,ref_keyword)
    qs = random.sample(qs, min(len(qs),20))
    # candidates with multiple predicates
    #cands = create_candidates(df, ref_keyword)
    cands = create_candidates_multiple_predicates(df,query_column,ref_keyword,2)
    print('cand count:',len(cands))
    # compute all query and candidate results
    all_res = get_all_results(df,query_column,qs).copy()
    all_res.update(get_all_results(df,query_column,cands))
    for q in qs:
        # filter candidates that do not contain query 
        if gencont:
            val_cands = get_valid_candidates(q,cands,all_res)
        else:
            val_cands = cands
        if len(val_cands) == 0:
            continue
        pq = private_query(q,epsilon,val_cands,all_res,sensitivity)
        print('query:',q)
        #print('query result:',all_res[q])
        print('private query:',pq)
        #print('private query result:',all_res[pq])
    
# query_column: ebay: 'Model Name', imdb: 'genres' 
# gencont='False': generalizing query does not need to be containing query result 
#main(dataset='imdb',keyword='Drama,Short',query_column='genres',gencont=False)
main(dataset='ebay',keyword='apple',query_column='Model Name',gencont=True)
# Out:
# 25204
# 29968
# query count 57
# cand count: 1596
# query: Watch smartwatch marked 12. similar apple iwatch 5 Compatible with iOS and Android.
# private query: ('apple iphone 7 32gb unlocked black', 'Watch smartwatch marked 12. similar apple iwatch 5 Compatible with iOS and Android.')
# query: series 4 apple watch 44mm
# private query: ('series 4 apple watch 44mm', 'apple watch series 5 gps cellular 44mm')
# query: apple watch series 3 38mm
# private query: ('apple watch series 3 38mm', 'apple watch series 3 42mm cellular')
# query: Charger Dock for apple Watch Charger with Build-in 3.3 FT USB Charging Cable
# private query: ('Charger Dock for apple Watch Charger with Build-in 3.3 FT USB Charging Cable', 'apple iphone 7 - 32gb - roségold')
# query: NEW apple watch series 6 GPS, 40mm Space Gray Aluminum Case With Black Sport
# private query: ('NEW apple watch series 6 GPS, 40mm Space Gray Aluminum Case With Black Sport', 'apple watch series 3 42mm Gps')
# query: apple watch series 3 38mm rose gold gps
# private query: ('apple watch series 3 38mm rose gold gps', 'apple iphone 7 32gb unlocked black')
# query: apple watch series 5 40mm
# private query: ('apple iphone 7 - 32gb - roségold', 'apple watch series 5 40mm')
# query: apple watch series 3 42mm cellular gps
# private query: ('apple watch series 3 42mm gps cellular new. Aluminum case, black sport band', 'apple watch series 3 42mm cellular gps')
# query: apple Watch Series 2 38mm Smart Watch Aluminum Case with Sport Band parts 38mm
# private query: ('apple watch series 3 38mm Used', 'apple Watch Series 2 38mm Smart Watch Aluminum Case with Sport Band parts 38mm')
# query: Smart Bracelet Watch Fitness Tracker Black/ Red Strap iwatch apple samsung
# private query: ('Smart Bracelet Watch Fitness Tracker Black/ Red Strap iwatch apple samsung', 'apple watch series 3')
# query: apple watch series 5 gps cellular 44mm
# private query: ('apple watch series 3 gps 42mm', 'apple watch series 5 gps cellular 44mm')
# query: [apple] aipods pro
# private query: ('apple beats studios 2.0 wired fire engine red by Dre (ORIGINAL)', '[apple] aipods pro')
# query: apple watch series 4 44mm
# private query: ('apple watch series 3 42mm Gps', 'apple watch series 4 44mm')
# query: BEATS STUDIO apple genuine NEW-Unused
# private query: ('Smart Bracelet Watch Fitness Tracker Black/ Red Strap iwatch apple samsung', 'BEATS STUDIO apple genuine NEW-Unused')
# query: apple watch series 3 38mm cellular
# private query: ('series 4 apple watch 44mm', 'apple watch series 3 38mm cellular')
# query: apple watch series 3 42mm Gps
# private query: ('[apple] aipods pro', 'apple watch series 3 42mm Gps')
# query: apple watch series 3 GPS 42mm Space Grey
# private query: ('apple watch series 3 GPS 42mm Space Grey', 'apple iphone xs 64gb gold')
# query: apple watch series 6 44mm cellular (RED) Brand New sealed
# private query: ('apple watch series 6 44mm cellular (RED) Brand New sealed', 'apple watch series 3 nike 38mm')
# query: apple watch series 3 42mm
# private query: ('apple watch series 3 38mm rose gold gps', 'apple watch series 3 42mm')
# query: apple watch Sport
# private query: ('apple watch Sport', 'apple watch series 4')

# %%
#%%capture cap --no-stderr

# here, the candidates are generated by enumerating values in the domains of all columns except the query column ('Model Name')
import pandas as pd
import numpy as np
import itertools
import random
import itertools
import json
import pickle

def create_imdb(): 
    df = pd.read_csv('imdb.tsv', sep='\t', nrows=5000)
    #df = df.fillna('nan')
    return df.apply(lambda x: x.astype(str).str.lower())
    #return df

def create_ebay(): 
    df = pd.read_csv('ebay_product.csv')
    #df = df.fillna('nan')
    return df.apply(lambda x: x.astype(str).str.lower())
    #return df

def create_queries_nosave(df,query_column,ref_keyword):
    qs = df[df[query_column].str.contains(ref_keyword,na=False)][query_column].drop_duplicates().values
    return [[q] for q in qs] 

def create_queries(dataset_name,query_num,query_column,ref_keyword):
    if dataset_name=='ebay':
        df = create_ebay()
    elif dataset_name=='imdb':
        df = create_imdb()  
    qps = df[df[query_column].str.contains(ref_keyword,na=False)][query_column].drop_duplicates().values
    qs =[[q] for q in qps]
    print('NUM OF GENERATED QUERIES: ' + str(len(qs)))
    qs = random.sample(qs, min(len(qs),query_num))
    print('NUM OF QUERIES: ' + str(len(qs)))
    with open(dataset_name+'_queries.json', 'w') as f:
        json.dump(qs, f)
  
def read_queries(dataset_name):
    with open(dataset_name+'_queries.json', 'r') as f:
        qs = json.load(f)
    return qs

def create_candidates_columns(df,pred_cols,max_preds_num):
    df2=df[pred_cols].drop_duplicates()
    df2 = df2.dropna()
    preds = list(df2.values)
    if max_preds_num is None: 
        max_preds_num = len(preds)
    if len(preds) > max_preds_num:
        preds = random.sample(preds, max_preds_num)
    return preds

# _conjunctive
def get_all_cand_results(df,pred_cols,preds,query_type):  
    df2 = df[pred_cols]
    res = {}
    for q in preds:
        q = np.array(list(q))
        # making the query a readable string
        predstr = [str(z)+' = '+str(w) for (z,w) in zip(pred_cols,q)]
        qstr = query_type.join(predstr) 
        #
        #res[str(q)] = set(df[(df2 == q).all(1)].index)
        res[qstr] = set(df[(df2 == q).all(1)].index)
    return res

# _disjunctive
def get_all_cand_results_disjunctive(df,pred_cols,preds,query_type):  
    dfs = {pc:df[[pc]] for pc in pred_cols}
    res = {}
    for p in preds:
        # making the query a readable string
        predstr = [str(z)+' = '+str(w) for (z,w) in zip(pred_cols,p)]
        qstr = query_type.join(predstr) 
        #
        res[qstr] = set()
        for (pc,q) in zip(pred_cols,p):
            df2 = dfs[pc]
            q = np.array(list([q]))
            res[qstr] = res[qstr].union(set(df[(df2 == q).all(1)].index))  
    return res
    
    
def utility1(real_query_res, cand_res):
    return len(cand_res.intersection(real_query_res))/len(cand_res)
    
def utility2(real_query_res, cand_res):
    return len(cand_res.intersection(real_query_res))*(min(len(cand_res),len(real_query_res))/(max(len(cand_res),len(real_query_res))+1))
    
def utility3(real_query_res, cand_res):
    if real_query_res.issubset(cand_res): 
        return 1.0/(len(cand_res.difference(real_query_res))+1)
    else: 
        return 0
    return len(cand_res.intersection(real_query_res))/(len(cand_res.symmetric_difference(real_query_res))+1)

def cands_utility(cands,real_query,res,utility_fn):
    return [utility_fn(res[real_query],res[c]) for c in cands]

def private_query(real_query,epsilon,cands,res,sensitivity,utility_fn):
    # get the score of all candidates
    scores_all = cands_utility(cands,real_query,res,utility_fn)
    cands_small = []
    scores = []
    for i in range(len(scores_all)):  
        if scores_all[i] != 0:
            scores.append(scores_all[i])
            cands_small.append(cands[i])
        elif len(scores)<200:
            scores.append(scores_all[i])
            cands_small.append(cands[i])
    cands = cands_small.copy()
    #print('NUM OF CONSIDERED CANDIDATES: %d' %(len(cands)))
    # exponential mechanism
    # sensitivity is assumed to be 1
    # Calculate the probability for each element, based on its score
    probabilities = [np.exp(epsilon * s / (2 * sensitivity)) for s in scores]
    # Normalize the probabilties so they sum to 1
    probabilities = probabilities / np.linalg.norm(probabilities, ord=1)
    # Choose a candidate based on the probabilities
    private_query_inx = np.random.choice(list(range(0,len(scores))), 1, p=probabilities)[0]
    
    max_utility = max(scores)
    private_query_utility = scores[private_query_inx]
    if max_utility != 0: 
        print('QUERY: ',real_query)
        print('NUM OF CANDIDATES THAT CONTAIN THE QUERY: %d' % sum(u!=0 for u in scores))
        print('MAX UTILITY: '+str(max_utility))
        print('MAX UTILITY QUERY: '+str(cands[scores.index(max_utility)]))
        print('PRIVATE QUERY UTILITY: '+str(private_query_utility))
        print('PRIVATE QUERY: ',cands[private_query_inx])
    else:
        return cands[private_query_inx], -1
    if private_query_utility == 0:
        return cands[private_query_inx], 1
    else:
        return cands[private_query_inx], 0

# candidate preparation
def preprocess(query_type,max_preds_num,dataset_name):
    if dataset_name=='imdb':
        df = create_imdb()
        space_cols = [['startYear']]
    if dataset_name=='ebay':
        df = create_ebay()
        #space_cols = [['Manufacturer'],['Title'],
        #              ['Carrier','Color Category'],['Carrier','Manufacturer']]
        space_cols = [['Manufacturer'],['Carrier'],['Color Category'],['Title'],
                      ['Carrier','Color Category'],['Carrier','Manufacturer'],['Color Category','Manufacturer']]
    all_res = {}
    cands = []
    candstrs = []
    for pred_cols in space_cols: 
        # candidates with multiple column values as predicates
        cs = create_candidates_columns(df,pred_cols,max_preds_num)
        cands.extend(cs)
        # building the string of cands
        for c in cs:
            pstr = [str(z)+' = '+str(w) for (z,w) in zip(pred_cols,c)]
            predstr = query_type.join(pstr) 
            candstrs.append(predstr)
        #
        # compute the results of candidates
        all_res.update(get_all_cand_results(df,pred_cols,cs,query_type).copy())
    print('TOTAL NUM OF CANDIDATES: %d' % (len(cands)))
    
    with open(dataset_name+'_candidates.json', 'w') as f:
        json.dump(candstrs, f)
    with open(dataset_name+'_queryresults.json', 'wb') as f:
        pickle.dump(all_res, f)
    return df,all_res,candstrs


#def run_queries(dataset_name,query_type,query_num,all_res,cands,query_column):
def run_queries(dataset_name,query_type,query_num,query_column):
    # read dataset and load preprocessed data
    if dataset_name=='imdb':
        df = create_imdb()
    if dataset_name=='ebay':
        df = create_ebay()
    with open(dataset_name+'_candidates.json', 'r') as f:
        cands = json.load(f)
    with open(dataset_name+'_queryresults.json', 'rb') as f:
        all_res = pickle.load(f)
    # read queries    
    qs = read_queries(dataset_name)
    print('NUM OF QUERIES: ' + str(len(qs)))
    print('---------------------------')
    #
    epsilon = 1 
    sensitivity = 1
    # compute candidate results
    q_res = get_all_cand_results(df,[query_column],qs,query_type)
    all_res.update(q_res)
    zero_max_utility = 0
    zero_private_utility = 0
    # make queries string
    qstrs = [query_column+' = '+q[0] for q in qs]
    fns = [utility1,utility2,utility3]
    zero_max_utilities = [0,0,0]
    zero_private_utilities = [0,0,0]
    
    for i in range(len(qs)): 
        q = qstrs[i]
        cands_query = [c for c in cands if qs[i][0] not in c]
        #print('NUM OF CANDIDATES FOR THIS QUERY: %d' % (len(cands_query)))
        print('---------------------------')
        for i in range(len(fns)):
            utility_fn = fns[i]
            print('UTILIT FUNC %d' %(i))
            pq, pqu = private_query(q,epsilon,cands_query,all_res,sensitivity,utility_fn)
            
            if pqu == -1: 
                #zero_max_utility += 1
                zero_max_utilities[i] +=1
            else:
                #zero_private_utility += pqu
                zero_private_utilities[i] += pqu
            print('---------------------------')
                
    for i in range(len(fns)):  
        print('UTILITY FUNC %d: %d OUT OF %d QUERIES DO NOT HAVE CONTAINING QUERIES'% (i, zero_max_utilities[i],len(qs)))
        print('UTILITY FUNC %d: %d OUT OF %d QUERIES HAVE CONTAINING QUERIES AND ZERO UTILITY PRIVATE QUERIES'% (i, zero_private_utilities[i],len(qs)))
            

    #print('%d OUT OF %d QUERIES DO NOT HAVE CONTAINING QUERIES'% (zero_max_utility,len(qs)))
    #print('%d OUT OF %d QUERIES HAVE CONTAINING QUERIES AND ZERO UTILITY PRIVATE QUERIES'% (zero_private_utility,len(qs)))
            

query_column='Model Name'
keyword='samsung galaxy'
##keyword='samsung galaxy note20 5g'
##keyword='apple'
query_type = ' OR '
##query_type = ' AND '
max_preds_num = 500#None
query_num = 50
dataset_name='ebay'

#create_queries(dataset_name,query_num,query_column,keyword)

#df,all_res,candstrs = preprocess(query_type,max_preds_num,dataset_name)
run_queries(dataset_name,query_type,query_num,query_column)

#df,all_res,cands = preprocess(dataset='imdb')
#run_queries(df,all_res,cands,keyword='Drama,Short',query_column='genres',gencont=True)
# Out:
# NUM OF QUERIES: 50
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = carte mere samsung galaxy a5 2016 a510f motherboard for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = amplifier bluetooth motorcycle mp3 stereo speaker audio system radio usb tf
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = carte mere samsung galaxy a5 2016 a510f motherboard for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = 3x r39 e14 reflector spotlight bulb indoor outdoor lighting replace bulb 25w
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = carte mere samsung galaxy a5 2016 a510f motherboard for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = rare #2005 hamtaro ham ham electronic figure keychain european #mosc
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy z fold2 5g 256gb mystic bronze kr brand new korean model
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = 20x dc stecker buchse kupplung hohlstecker hohlbuchse 5,5x2,1mm~ adspo
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy z fold2 5g 256gb mystic bronze kr brand new korean model
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = d3000 wired headset headphone with noise cancelling mic for pc computer learning
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy z fold2 5g 256gb mystic bronze kr brand new korean model
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = 20x dc stecker buchse kupplung hohlstecker hohlbuchse 5,5x2,1mm~ adspo
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s8 active g892a 64gb at&t wireless only smart cellphone gold v302
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = sony playstation 3 ps3 slim 120 gb console bundle
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s8 active g892a 64gb at&t wireless only smart cellphone gold v302
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = 2x replacement foam ear pads earpad cup cover kit for skullcandy grind headphone
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy s8 active g892a 64gb at&t wireless only smart cellphone gold v302
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = 6pack magnétique écouteurs câble usb enrouleurs corder winder string
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s7 sm-g930f 5,1" 32gb ohne simlock smartphone - white pearl for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = x7 plus 5.1 inch handheld game console 8gb built - in 200 games (blue red) ne
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s7 sm-g930f 5,1" 32gb ohne simlock smartphone - white pearl for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = xbox 360 slim model 1439 120gb storage oem controller and cables tested
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy s7 sm-g930f 5,1" 32gb ohne simlock smartphone - white pearl for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = smart watch étanche pression artérielle fréquence cardiaque fitness band trac
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy a51 sm-a515f/dsn - 128gb - prism crush blue (ohne simlock) (dual-sim) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = 1piece wireless home security system l 1 battery-powered wi-fi 1 pc (camera)
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy a51 sm-a515f/dsn - 128gb - prism crush blue (ohne simlock) (dual-sim) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = smart health
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy a51 sm-a515f/dsn - 128gb - prism crush blue (ohne simlock) (dual-sim) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = yison ® ex210 in ear stereo headphones suitable for huawei nova 5i pro
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy buds pro - phantom black, new, sealed never opened
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = meih 85-250v wi-fi smart thermostat weekly programmable thermostat app c0y5
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy buds pro - phantom black, new, sealed never opened
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = jaybird x4 in ear wireless headphones - grey
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy buds pro - phantom black, new, sealed never opened
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = tuya smart wireless gateway hub smart home bridge smart life m7l9
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s7
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 40
# MAX UTILITY: 1.0
# MAX UTILITY QUERY: Carrier = verizon, page plus cellular, unlocked, straight talk, at&t
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = brand new in box wahoo tickr heart rate monitor
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s7
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 40
# MAX UTILITY: 1.476923076923077
# MAX UTILITY QUERY: Color Category = gold
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = pc engine white console + av booster output accessory unit!
# ---------------------------
# UTILIT FUNC 2
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy a50 - 128gb - schwarz (ohne simlock) (dual-sim)
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = sega genesis series 2 gaming system
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy a50 - 128gb - schwarz (ohne simlock) (dual-sim)
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 4.125582738561822e-05
# PRIVATE QUERY:  Carrier = nan OR Color Category = nan
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy a50 - 128gb - schwarz (ohne simlock) (dual-sim)
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = brand new sony playstation 5-disc edition with 3 games! sealed
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy avant, 16gb - (t-mobile) works, please read!! 39978
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = iphone 6
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy avant, 16gb - (t-mobile) works, please read!! 39978
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = jaybird x4 in ear wireless headphones - grey
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy avant, 16gb - (t-mobile) works, please read!! 39978
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = game xbox 360 helboy with record
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s9 64gb unlocked - immaculate condition
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = powera enhanced wired controller for nintendo switch - mario vintage star
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s9 64gb unlocked - immaculate condition
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = wireless earbuds
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy s9 64gb unlocked - immaculate condition
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = panasonic rp-hje125 in ear earphones headphones orange-ovp contaminated
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy a5 (2017) sm-a520f 32gb peach cloud (unlocked) smartphone
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = mpow h17 anc bluetooth headphones
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy a5 (2017) sm-a520f 32gb peach cloud (unlocked) smartphone
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = final audio design
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy a5 (2017) sm-a520f 32gb peach cloud (unlocked) smartphone
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = wireless remote control doorbell 32 tune songs smart security door ring
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s20 fe sm-g780f/ds - 128gb - cloud lavender (sbloccato) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = nintendo ctr-001
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s20 fe sm-g780f/ds - 128gb - cloud lavender (sbloccato) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = vin diesel wheelman pc game cd dvd-rom new blister c2
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy s20 fe sm-g780f/ds - 128gb - cloud lavender (sbloccato) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = super mario bros wallio's forest nes software
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy note5 smartphone sprint n920p android smartphone cellphone note5
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = brand new sony playstation 5-disc edition with 3 games! sealed
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy note5 smartphone sprint n920p android smartphone cellphone note5
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = k5 watch heart rate smart monitor blood oxygen pressure bracelet band waterproof
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy note5 smartphone sprint n920p android smartphone cellphone note5
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = unimax
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = gblue s80 wireless bluetooth stereo sports headphones for samsung galaxy a8 + (2018)
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 8.251505899826719e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = nintendo wii console bundle
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = gblue s80 wireless bluetooth stereo sports headphones for samsung galaxy a8 + (2018)
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 0.00016502330954247288
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = apple ipad mini 1st gen. black white 16gb 32gb 64gb wifi ios 9.3.5
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = gblue s80 wireless bluetooth stereo sports headphones for samsung galaxy a8 + (2018)
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125923175310476e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = used untested apple iphone model a1387 white only good for parts or repair
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy tab a 2018 sm-t595 lte 4g black (10.5) * new!!! *
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = bakeey anti-lost silicone watch band for xiaomi mi band 5 smart watch
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy tab a 2018 sm-t595 lte 4g black (10.5) * new!!! *
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = kingpin tv streaming device
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy tab a 2018 sm-t595 lte 4g black (10.5) * new!!! *
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = 1080p 47 led ip security camera cctv wifi pan/tilt ptz ir dome smart cam home pp
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = bnib samsung galaxy ace s5830 black factory unlocked smartphone oem
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = nintendo ctr-001
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = bnib samsung galaxy ace s5830 black factory unlocked smartphone oem
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = us_ usb fast charging dock base charger for garmin vivosmart hr hr+ approach x40
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = bnib samsung galaxy ace s5830 black factory unlocked smartphone oem
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = x96 mate android 10.0 tv box 2021 model – quad core – 4gb ram 32gb/64gb rom
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy a3 - 16gb - midnight black (unlocked/simfree) grade a
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = display 100% genuine samsung s7 edge sm-g935f frame + flat broken glass
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy a3 - 16gb - midnight black (unlocked/simfree) grade a
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = brand new in box wahoo tickr heart rate monitor
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy a3 - 16gb - midnight black (unlocked/simfree) grade a
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = x96 mate android 10.0 tv box 2021 model – quad core – 4gb ram 32gb/64gb rom
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s21 5g sm-g991b/ds - 128gb - phantom violet (ohne simlock) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 8.251505899826719e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = 2x replacement foam ear pads earpad cup cover kit for skullcandy grind headphone
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s21 5g sm-g991b/ds - 128gb - phantom violet (ohne simlock) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 0.00016502330954247288
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = 3x r39 e14 reflector spotlight bulb indoor outdoor lighting replace bulb 25w
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy s21 5g sm-g991b/ds - 128gb - phantom violet (ohne simlock) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125923175310476e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = 1.54inch tft square men bluetooth 5.0 fitness tracker smart watch bracelet
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s21+ 5g sm-g996b/ds - 256gb - phantom silver
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = microsoft xbox launch edition 8gb console w/ 3 controllers & component cables
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s21+ 5g sm-g996b/ds - 256gb - phantom silver
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = panasonic rp-hje125 in ear earphones headphones orange-ovp contaminated
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy s21+ 5g sm-g996b/ds - 256gb - phantom silver
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = apple ipad 32gb 9.7 inch tablet wi-fi + cellular space grey 5. gen 2017 (
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = xt11 magnetic wireless bluetooth earphones headphones for samsung galaxy a8
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = wireless remote control doorbell 32 tune songs smart security door ring
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = xt11 magnetic wireless bluetooth earphones headphones for samsung galaxy a8
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = deals set nintendo 3ds console monhanset/32
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = xt11 magnetic wireless bluetooth earphones headphones for samsung galaxy a8
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = hks front pipe 3306-sm002 lancer evolution 4g63 ct9a ix 05 03-07 09 ct9a viii 03
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = new! samsung galaxy smartphone s7 32gb sm-g930 g930f g930v _ 12 months warranty ita
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = nintendo 64 n64 - controller pad hello mac (rare) - japan
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = new! samsung galaxy smartphone s7 32gb sm-g930 g930f g930v _ 12 months warranty ita
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = anarn hd 1080p wireless wifi ip security camera system night vision 2tb cctv nvr
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = new! samsung galaxy smartphone s7 32gb sm-g930 g930f g930v _ 12 months warranty ita
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = xbox 360 slim model 1439 120gb storage oem controller and cables tested
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = 2x sportarmband für samsung galaxy fit sm-r370 fitness tracker halterung
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = fitbit ionic smart watch
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = 2x sportarmband für samsung galaxy fit sm-r370 fitness tracker halterung
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = withings steel hr sport smartwatch with three bracelets
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = 2x sportarmband für samsung galaxy fit sm-r370 fitness tracker halterung
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = 2020 samsung galaxy tab a7 sm-t500 only wi-fi 3g/64g 10.4" - dark grey - slim
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = smartphone samsung galaxy s8 sm-g950 - 64 go - bleu océan for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = nintendo wii console bundle
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = smartphone samsung galaxy s8 sm-g950 - 64 go - bleu océan for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = elpa re-11(iv) radio earphone japan ver. new / free-shipping
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = smartphone samsung galaxy s8 sm-g950 - 64 go - bleu océan for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = headphone jack adapter 3.5mm 4 pole copper nickel plating white 9pcs
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy buds+
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 0.0001237725884974008
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = apple watch 42mm edelstahl case white sportarmband (mj3v2fd/a) for sale online
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy buds+
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 0.000371302446470564
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = lovoski 4 pairs silicone replacement eartips ear hook for beats x beats 3.0
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy buds+
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1260934147549104e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = iphone 6
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy watch 42mm lte
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 8.251505899826719e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = replacement ear cushion headset for akg k430 k450 k451 k480 q460 foam ear pads*
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy watch 42mm lte
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 0.00016502330954247288
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = c1pro 0,96 "écran smart wristband moniteur de fréquence cardiaque fitness band
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy watch 42mm lte
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125923175310476e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = [w/box] nintendo game boy console light clear yellow toysrus tested from japan
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy note20 lte n980fd dual 8+256gb gray
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = nintendo 2ds boxed
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy note20 lte n980fd dual 8+256gb gray
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = usedgame ps1 ps playstation 1 blood factory slps00235 from japan for sale online
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy note20 lte n980fd dual 8+256gb gray
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = [w/box] nintendo game boy console light clear yellow toysrus tested from japan
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s7 active g891a 32gb at&t wireless only smart cellphone gold v028
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = silicone sport strap band for apple watch iwatch series 6 se 5 4 3 38/40/42/44mm
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s7 active g891a 32gb at&t wireless only smart cellphone gold v028
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = microsoft xbox launch edition 8gb console w/ 3 controllers & component cables
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy s7 active g891a 32gb at&t wireless only smart cellphone gold v028
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = jabra elite 45e bluetooth wireless headset, 8h battery, voice command
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy a5 sm-a500fu - 16gb - champagnergold (ohne simlock) smartphone for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = crashed dji mavic mini drone *read description* for parts/repair, listing 14
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy a5 sm-a500fu - 16gb - champagnergold (ohne simlock) smartphone for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = gblue s80 stereo bluetooth wireless sports headset for samsung galaxy a41
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy a5 sm-a500fu - 16gb - champagnergold (ohne simlock) smartphone for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = touch screen glass for b&r 4pp045.0571-k33 4pp045-0571-k33 one year warranty new
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s21 sm-g9910 256gb 8gb ram (factory unlocked) 6.2" 64mp
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = apple watch 42mm edelstahl case white sportarmband (mj3v2fd/a) for sale online
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s21 sm-g9910 256gb 8gb ram (factory unlocked) 6.2" 64mp
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = wireless remote control doorbell 32 tune songs smart security door ring
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy s21 sm-g9910 256gb 8gb ram (factory unlocked) 6.2" 64mp
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = microsoft xbox launch edition 8gb console w/ 3 controllers & component cables
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy note 20 ultra 5g sm-n986u 128gb latest smartphone unlocked
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = gblue s80 stereo bluetooth wireless sports headphones for jinga neon
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy note 20 ultra 5g sm-n986u 128gb latest smartphone unlocked
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = *nice!* apple iphone 5 16gb black bundle: phone, case, & new screen protector!
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy note 20 ultra 5g sm-n986u 128gb latest smartphone unlocked
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = nintendo wii console bundle
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s8+ sm-g955 - 64gb - blue coral broken lcd as is #vz2
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = kingpin tv streaming device
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s8+ sm-g955 - 64gb - blue coral broken lcd as is #vz2
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = meih 85-250v wi-fi smart thermostat weekly programmable thermostat app c0y5
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy s8+ sm-g955 - 64gb - blue coral broken lcd as is #vz2
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = bakeey anti-lost silicone watch band for xiaomi mi band 5 smart watch
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy trend gt-s7560 - 4 go - blanc (désimlocké) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = oukitel wp6 6/128gb 48mp camera 10000mah face id ip68 outdoor smartphone
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy trend gt-s7560 - 4 go - blanc (désimlocké) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = apple watch series 5 44mm cellular
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy trend gt-s7560 - 4 go - blanc (désimlocké) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = k5 watch heart rate smart monitor blood oxygen pressure bracelet band waterproof
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy tab s6 lite, 128gb, oxford gray (wi-fi) w/ s pen - sm-p610nzaexar
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = 2 cases for garmin vivoactive 3 blue black kwmobile for sale online
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy tab s6 lite, 128gb, oxford gray (wi-fi) w/ s pen - sm-p610nzaexar
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = sony headphones 4 pairs - read all details
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy tab s6 lite, 128gb, oxford gray (wi-fi) w/ s pen - sm-p610nzaexar
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = nintendo gameboy color | game boy green new display disc-vgc
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = -new sealed- samsung galaxy tab a7 2020 wifi
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = i12 pro max smartphone
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = -new sealed- samsung galaxy tab a7 2020 wifi
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = xidier high definition stereo headset headphones suitable for fujitsu arrows u
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = -new sealed- samsung galaxy tab a7 2020 wifi
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = yison ® ex210 in ear stereo headphones suitable for huawei nova 5i pro
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy tab 2 7.0 tablet original box included
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = 1.54inch tft square men bluetooth 5.0 fitness tracker smart watch bracelet
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy tab 2 7.0 tablet original box included
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = tamagotchi cheeks chan sui kore pink
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy tab 2 7.0 tablet original box included
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = mpow h17 anc bluetooth headphones
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s7 edge sm-g935 - 32gb - gold platinum (ohne simlock) smartphone for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = vintage nintendo 64 plus joy sticks
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s7 edge sm-g935 - 32gb - gold platinum (ohne simlock) smartphone for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = final audio design
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy s7 edge sm-g935 - 32gb - gold platinum (ohne simlock) smartphone for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = 720p pir 7inch wifi video doorphone intercom doorbell ip camera ir night vision
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy watch sm-r805 46mm silber gehäuse mit klassisches armband in onyx black - lte (telekom mobilfunk) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = headphone jack adapter 3.5mm 4 pole copper nickel plating white 9pcs
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy watch sm-r805 46mm silber gehäuse mit klassisches armband in onyx black - lte (telekom mobilfunk) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = samsung galaxy watch sm-r815 42mm schwarz gehäuse mit klassisches armband in onyx black - lte (telekom mobilfunk) for sale online
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy watch sm-r805 46mm silber gehäuse mit klassisches armband in onyx black - lte (telekom mobilfunk) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = kreative balance adler wahrzeichen gebäude dekoration geschenk q0z2
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy a12
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 6
# MAX UTILITY: 0.1
# MAX UTILITY QUERY: Carrier = vodafone OR Manufacturer = samsung
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = yison ex210 intra-atrial stereo headset for asus zenfone max plus m2
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy a12
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 6
# MAX UTILITY: 0.18181818181818182
# MAX UTILITY QUERY: Carrier = vodafone OR Manufacturer = samsung
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = big deal: 65″ 4k new led roku ultra hd tv
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy a12
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 1
# MAX UTILITY: 3.9621221126035104e-05
# MAX UTILITY QUERY: Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = nest hello smart wi-fi video doorbell night vision two way audio us stock
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy j5 duos sm-j530f 16gb schwarz (ohne simlock) smartphone (2017) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 8.251505899826719e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = d3000 wired headset headphone with noise cancelling mic for pc computer learning
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy j5 duos sm-j530f 16gb schwarz (ohne simlock) smartphone (2017) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 0.00016502330954247288
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = j10 3g phone call tablet android 10 2gb 32gb wifi gps tablet + 16gb tf card k1b
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy j5 duos sm-j530f 16gb schwarz (ohne simlock) smartphone (2017) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125923175310476e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = tuya smart wireless gateway hub smart home bridge smart life m7l9
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s5 sm-g900f - 16gb - shimmery white (ohne simlock) smartphone for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = for nokia 8 wireless bluetooth magnetic band neck sport stereo headset
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s5 sm-g900f - 16gb - shimmery white (ohne simlock) smartphone for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = deals set nintendo 3ds console monhanset/32
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy s5 sm-g900f - 16gb - shimmery white (ohne simlock) smartphone for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = final audio design
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy a5 a520f 2017 32gb gold (unlocked)
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = ipsky earphones headphones wired headset earbuds with mic for samsung galaxy s8
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy a5 a520f 2017 32gb gold (unlocked)
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = samsung galaxy j3 (6 duos) - top condition
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy a5 a520f 2017 32gb gold (unlocked)
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = langsdom headphone varies colors
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy tab s6 sm-t867 128gb, wi-fi + 4g (t-mobile), 10.5 in - mountain …
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = wireless doorbell kit - period style visitor chrome push on a tudor oak plinth
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy tab s6 sm-t867 128gb, wi-fi + 4g (t-mobile), 10.5 in - mountain …
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = c1 monitoring hifi headphones 50mm dynamic wooden earphone over-the -ear bass
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy tab s6 sm-t867 128gb, wi-fi + 4g (t-mobile), 10.5 in - mountain …
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = vin diesel wheelman pc game cd dvd-rom new blister c2
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy a3 (2017) blue mist sm-a320fl vgc
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = jvc riptide ha-fx8 in-ear only headphones - violet
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy a3 (2017) blue mist sm-a320fl vgc
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = vintage nintendo 64 plus joy sticks
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy a3 (2017) blue mist sm-a320fl vgc
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = shanling me500 knowls dual balanced armature driver hifi stereo in-ear earphones
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s10 sm-g973f - 128gb - prism black (e-plus+) (dual-sim) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = 1pc door viewer smart wifi door camera peephole viewer visual doorbell
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s10 sm-g973f - 128gb - prism black (e-plus+) (dual-sim) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = for nokia 8 wireless bluetooth magnetic band neck sport stereo headset
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy s10 sm-g973f - 128gb - prism black (e-plus+) (dual-sim) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = steel band smart watch heart rate blood pressure monitor sport multifunction mod
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy note10+ 5g sm-n976b - 256gb - aura glow (t-mobile) (einzel-sim) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = digital smart body scale bmi mass monitor record wireless weight management wifi
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy note10+ 5g sm-n976b - 256gb - aura glow (t-mobile) (einzel-sim) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = mpow h17 anc bluetooth headphones
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy note10+ 5g sm-n976b - 256gb - aura glow (t-mobile) (einzel-sim) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = michael kors gen 3 smart watch authentic digital wrist watch mkt5022 dm446
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s20 5g
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 19
# MAX UTILITY: 1.0
# MAX UTILITY QUERY: Carrier = page plus cellular, verizon, at&t, boost mobile, unlocked
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = microsoft xbox launch edition 8gb console w/ 3 controllers & component cables
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s20 5g
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 19
# MAX UTILITY: 0.8181818181818182
# MAX UTILITY QUERY: Carrier = at&t
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = 2x goowls camera outdoor 1080p hd pan tilt 2g wifi home surveillance alexa night for sale online
# ---------------------------
# UTILIT FUNC 2
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy a41 sm-a415f/ds - 64gb - prism crush black (desbloqueado) (sim doble) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 2
# MAX UTILITY: 0.024390243902439025
# MAX UTILITY QUERY: Color Category = negro
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = j10 3g phone call tablet android 10 2gb 32gb wifi gps tablet + 16gb tf card k1b
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy a41 sm-a415f/ds - 64gb - prism crush black (desbloqueado) (sim doble) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 2
# MAX UTILITY: 0.023809523809523808
# MAX UTILITY QUERY: Color Category = negro
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = replacement ear cushion headset for akg k430 k450 k451 k480 q460 foam ear pads*
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy a41 sm-a415f/ds - 64gb - prism crush black (desbloqueado) (sim doble) for sale online
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 2
# MAX UTILITY: 0.024390243902439025
# MAX UTILITY QUERY: Color Category = negro
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = silicone sport strap band for apple watch iwatch series 6 se 5 4 3 38/40/42/44mm
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = phone samsung galaxy alpha g850f 4g 32gb grey ash perfectly level a
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = ipsky earphones headphones wired headset earbuds with mic for samsung galaxy s8
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = phone samsung galaxy alpha g850f 4g 32gb grey ash perfectly level a
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = xidier high definition stereo headset headphones suitable for fujitsu arrows u
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = phone samsung galaxy alpha g850f 4g 32gb grey ash perfectly level a
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = super mario bros wallio's forest nes software
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = headphones bluetooth wireless for range samsung galaxy note 3/ 4/5/ 6/7/ 8/9/
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = apple watch 42mm edelstahl case white sportarmband (mj3v2fd/a) for sale online
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = headphones bluetooth wireless for range samsung galaxy note 3/ 4/5/ 6/7/ 8/9/
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = polsini smart watch con cinturino morbido di ricambio per polar v800 grigio
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = headphones bluetooth wireless for range samsung galaxy note 3/ 4/5/ 6/7/ 8/9/
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = super mario bros wallio's forest nes software
# ---------------------------
# ---------------------------
# UTILIT FUNC 0
# QUERY:  Model Name = samsung galaxy s7 sm-g930 - 32gb - black onyx
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = corseca smart bracelet wristband watch heart rate monitor fitness tracker bfit
# ---------------------------
# UTILIT FUNC 1
# QUERY:  Model Name = samsung galaxy s7 sm-g930 - 32gb - black onyx
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.125582738561822e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0.0
# PRIVATE QUERY:  Manufacturer = vintage nintendo 64 plus joy sticks
# ---------------------------
# UTILIT FUNC 2
# QUERY:  Model Name = samsung galaxy s7 sm-g930 - 32gb - black onyx
# NUM OF CANDIDATES THAT CONTAIN THE QUERY: 3
# MAX UTILITY: 4.1257529499133594e-05
# MAX UTILITY QUERY: Carrier = nan OR Color Category = nan
# PRIVATE QUERY UTILITY: 0
# PRIVATE QUERY:  Manufacturer = big deal: 65″ 4k new led roku ultra hd tv
# ---------------------------
# UTILITY FUNC 0: 0 OUT OF 50 QUERIES DO NOT HAVE CONTAINING QUERIES
# UTILITY FUNC 0: 50 OUT OF 50 QUERIES HAVE CONTAINING QUERIES AND ZERO UTILITY PRIVATE QUERIES
# UTILITY FUNC 1: 0 OUT OF 50 QUERIES DO NOT HAVE CONTAINING QUERIES
# UTILITY FUNC 1: 49 OUT OF 50 QUERIES HAVE CONTAINING QUERIES AND ZERO UTILITY PRIVATE QUERIES
# UTILITY FUNC 2: 2 OUT OF 50 QUERIES DO NOT HAVE CONTAINING QUERIES
# UTILITY FUNC 2: 48 OUT OF 50 QUERIES HAVE CONTAINING QUERIES AND ZERO UTILITY PRIVATE QUERIES
